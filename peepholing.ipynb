# %% [markdown]
# # Learning Python;'s constant optimisations and peepholing mechanisms

# %%
x = 600
y=600

# %%
print(x,y)
# Out:
# 600 600

# %%
print(id(x))
print(id(y))
# Out:
# 126374695287376
# 126374695287600

# %%
def func(params = []):
    params.append(1)
    print(params)
func()
func()
# Out:
# [1]
# [1, 1]

# %%
x=6



def func():
    global x
    x=5
    non local


    print(id(x))

func()
print(x)
print(id(x))
# Out:
# 11755816
# 5
# 11755816

# %%
x = 257
y = 257

print(id(x))
print(id(y))
# Out:
# 127968820085232
# 127968820084976

# %%
x = 600
y = 600
print(id(x))
print(id(y))
# Out:
# 127968820085168
# 127968820085200
